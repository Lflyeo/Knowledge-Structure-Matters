# %%
# %load_ext autoreload
# %autoreload 2
# 使用示例和测试
from MathVocabularyExtraction2 import BERTVocabularyDiscoverer
sample_dataset = [
        "小明有5个苹果，小红比小明多3个苹果，问小红有多少个苹果？",
        "小华的书本数量是小明的2倍，小明有8本书，问小华有多少本书？",
        "甲班有30名学生，乙班比甲班少5名学生，问乙班有多少名学生？",
        "一个篮子里有8个鸡蛋，又放进去4个，现在一共有多少个鸡蛋？",
        "商品原价200元，打8折后的价格是多少元？",
        "汽车以每小时60公里的速度行驶，3小时能走多少公里？",
        "长方形的长是15米，宽是长的三分之二，面积是多少平方米？",
        "爸爸比儿子大25岁，5年后爸爸的年龄是儿子的3倍，现在各多少岁？",
        "一箱饮料有24瓶，每瓶3元，买3箱需要多少元？",
        "三角形面积是底乘高除以2，底10厘米，高8厘米，面积是多少平方厘米？"
    ]

# def test_hanlp_extraction():
#     """测试HanLP词汇提取功能"""
    
#     # 示例数学应用题数据集
#     sample_dataset = [
#         "小明有5个苹果，小红比小明多3个苹果，问小红有多少个苹果？",
#         "小华的书本数量是小明的2倍，小明有8本书，问小华有多少本书？",
#         "甲班有30名学生，乙班比甲班少5名学生，问乙班有多少名学生？",
#         "一个篮子里有8个鸡蛋，又放进去4个，现在一共有多少个鸡蛋？",
#         "商品原价200元，打8折后的价格是多少元？",
#         "汽车以每小时60公里的速度行驶，3小时能走多少公里？",
#         "长方形的长是15米，宽是长的三分之二，面积是多少平方米？",
#         "爸爸比儿子大25岁，5年后爸爸的年龄是儿子的3倍，现在各多少岁？",
#         "一箱饮料有24瓶，每瓶3元，买3箱需要多少元？",
#         "三角形面积是底乘高除以2，底10厘米，高8厘米，面积是多少平方厘米？"
#     ]
    
#     extractor = MathVocabularyExtractor()
#     results = extractor.comprehensive_extraction(sample_dataset)
    
#     # # 生成报告
#     # report = extractor.generate_extraction_report(results)
#     # print(report)
    
#     return results
# test_hanlp_extraction()

# %%
extractor = BERTVocabularyDiscoverer()
# Out:
# model.safetensors:   0%|          | 0.00/412M [00:00<?, ?B/s]
# F:\anaconda_envs_dir\py4dm\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in F:\HF_HOME\hub\models--bert-base-chinese. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
# %time
extractor.discover_units_from_corpus(sample_dataset)
# Out:
# Building prefix dict from the default dictionary ...
# CPU times: total: 0 ns
# Wall time: 0 ns
# Dumping model to file cache C:\Users\jimso\AppData\Local\Temp\jieba.cache
# Loading model cost 0.923 seconds.
# Prefix dict has been built successfully.
# [{'word': '个',
#   'score': 1.5828357640180315,
#   'similarity': 0.8833974599838257,
#   'frequency': 5,
#   'type': 'discovered_unit'},
#  {'word': '倍',
#   'score': 1.3643394162684974,
#   'similarity': 0.8477117419242859,
#   'frequency': 4,
#   'type': 'discovered_unit'},
#  {'word': '元',
#   'score': 1.3400805482456832,
#   'similarity': 0.8326388597488403,
#   'frequency': 4,
#   'type': 'discovered_unit'}]
